# %%
# csv파일을 읽어서 데이터프레임으로 만들기
import pandas as pd

data = pd.read_csv('../dataset/dailydialog_table_all.csv')

# %%
data
# Out:
#       dialog_id  turn speaker  \
# 0       tr_4466     1       A
# 1       tr_4466     2       B
# 2       tr_4466     3       A
# 3       tr_4466     4       B
# 4       tr_4466     5       A
# ...         ...   ...     ...
# 11099  tr_10060     6       B
# 11100  tr_10060     7       A
# 11101  tr_10060     8       B
# 11102  tr_10060     9       A
# 11103  tr_10060    10       B
#
#                                                utterance  emotion cause turn  \
# 0                 Hey , you wanna see a movie tomorrow ?    happy        [1]
# 1      Sounds like a good plan . What do you want to ...    happy        [1]
# 2                             How about Legally Blonde .  neutral        NaN
# 3      Ah , my girlfriend wanted to see that movie . ...  neutral        NaN
# 4                             Isn't that a scary movie ?  neutral        NaN
# ...                                                  ...      ...        ...
# ...

# %%
# data 의 emotion에 어떤 종류가 오는지
data['emotion'].unique()
# Out:
# array(['happy', 'neutral', 'angry', 'surprise', 'disgust', 'sad', 'fear',
#        'excited'], dtype=object)

# %%
data = pd.read_csv('../dataset/dailydialog_table.csv')
data
# Out:
#      dialog_id emotion  len
# 0      tr_4466   happy    9
# 1      tr_7536   angry   10
# 2       tr_754   happy    8
# 3      tr_4110   happy    5
# 4      tr_3432   happy    5
# ...        ...     ...  ...
# 1101    te_999   happy   12
# 1102   tr_9789   happy    7
# 1103    te_767     sad    6
# 1104    te_796   happy    8
# 1105  tr_10060   happy   10
#
# [1106 rows x 3 columns]

# %%
# len 순으로 정리
data.sort_values(by='len', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19312\683948086.py in <module>
#       1 # len 순으로 정리
# ----> 2 data.sort_values(by='len', ascending=False)
#
# c:\Users\Admin\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\Admin\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6320
#    6321             by = by[0]
# -> 6322             k = self._get_label_or_level_values(by, axis=axis)
#    6323
#    6324             # need to rewrap column in Series to apply key function
#
# ...
